# %%
# !pip install rake-nltk
# Out:
# ...
#   Created wheel for rake-nltk: filename=rake_nltk-1.0.4-py2.py3-none-any.whl size=7010 sha256=3764fece2c7686ee85a177288d1509f2696b7427b81cb3229cff6f85340cf47e
#   Stored in directory: C:\Users\iyerr\AppData\Local\pip\Cache\wheels\ef\92\fc\271b3709e71a96ffe934b27818946b795ac6b9b8ff8682483f
# Successfully built rake-nltk
# ...

# %%
with open('911.txt', 'r', encoding = 'utf-8') as file:
    lines = file.readlines()
    file.close()

text1 = ' '.join(lines)
text1
# Out:
# '9/11’ refers to the events that occurred on September 11th, 2001 during which members of al-Qaeda hijacked four airliners, resulting in suicide attacks against major targets in the United States of America.[1] Of the four aeroplanes, one struck the Pentagon, one crashed in a field in Pennsylvania, and the remaining two were flown into the Twin Towers in New York City.[2] Three thousand people lost their lives in the attacks, which President George W. Bush referred to as “a national tragedy.”[3] However, the consequences were to be long term. In the immediate aftermath, President Bush gave a simple explanation, stating, “America was targeted for attack because we’re the brightest beacon for freedom and opportunity in the world. And no one will keep that light from shining.”[4] Although a short explanation was given, President Bush knew that the causes for such an attack were far more complicated and the consequences even more so.\n \n  The causes of 9/11 can be split into two sub-hea
# ...

# %%
from rake_nltk import Rake

r = Rake(min_length=1, max_length=3) # Uses stopwords for english from NLTK, and all puntuation characters.

r.extract_keywords_from_text(text1)

r.get_ranked_phrases() # To get keyword phrases ranked highest to lowest.
# Out:
# ['shining .”[ 4',
#  'president george w',
#  'new york city',
#  'president bush knew',
#  'president bush gave',
#  'four main causes',
#  'united states support',
#  '11 ’ refers',
#  'united states',
#  'bush referred',
#  'four aeroplanes',
#  'arab states',
#  'years overflowing',
#  'western press',
#  'two sub',
#  'twin towers',
#  'simple explanation',
#  'short explanation',
#  'september 11th',
#  'remaining two',
#  'major targets',
#  'long term',
#  'immediate aftermath',
#  'explicitly declared',
#  'criminals …',
#  'british handed',
#  'brightest beacon',
#  'american support',
#  '50 years',
#  '“ letter',
#  'suicide attacks',
#  'one struck',
#  'one crashed',
#  'america ”',
#  '11 attacks',
#  'greatest crimes',
#  'consequences even',
#  '“ america',
#  '’',
#  'support',
#  'refers',
#  'causes',
#  '11',
#  '“',
#  'one',
#  'attacks',
#  'america',
#  'crimes',
#  'consequences',
#  'world',
#  'within',
#  'tyranny',
#  'targeted',
#  'suggested',
# ...

# %%
with open('ochem.txt', 'r', encoding = 'utf-8') as file:
    lines = file.readlines()
    file.close()

text2 = ' '.join(lines)
text2
# Out:
# "At first the study of organic chemistry involves understanding the energy\n and shapes of simple organic structures. Then the study progresses to more\n complicated three-dimensional structures and finally to the investigation of reactions\n of organic molecules. We use the theories of bonding and the facts about acidic or\n basic properties of the molecules to understand the overall picture of what is\n happening. But the overall goal is to improve mankind through the development of\n new and better processes to be applied in medicine, agriculture and biomedical\n science, that is to make life better. Thus we must be able to study difficult molecules\n too.\n As you proceed through organic chemistry you will write many different\n structures, and the writing gets easier with practice. But in the beginning it can be\n confusing. Always remember that carbon has four bonds!\n In writing an alkane such as pentane which has five carbon atoms. We\n could write it by just showing carbon a
# ...

# %%
from rake_nltk import Rake

r = Rake() # Uses stopwords for english from NLTK, and all puntuation characters.

r.extract_keywords_from_text(text2)

r.get_ranked_phrases() # To get keyword phrases ranked highest to lowest.
# Out:
# ['compound called cyclohexane written several different ways',
#  'write many different structures',
#  'carbon compounds also exist',
#  'points representing carbon atoms',
#  'organic chemistry involves understanding',
#  'called cyclic compounds',
#  'compounds becomes cumbersome',
#  'showing carbon atoms',
#  'five carbon atoms',
#  'make life better',
#  'simple organic structures',
#  'writing gets easier',
#  'present even though',
#  'write condensed structures',
#  'study difficult molecules',
#  'organic chemistry',
#  'carbon atoms',
#  'condensed structures',
#  'hydrogen atoms',
#  'organic molecules',
#  'could write',
#  'show carbon',
#  'writing structures',
#  'dimensional structures',
#  'thus understanding',
#  'better processes',
#  'write pentane',
#  'written',
#  'without writing',
#  'study progresses',
#  'shorthand methods',
#  'overall picture',
#  'overall goal',
#  'line structure',
#  'improve mankind',
#  'four bonds',
#  'complicated three',
# ...

# %%
with open('rsa.txt', 'r', encoding = 'utf-8') as file:
    lines = file.readlines()
    file.close()

text3 = ' '.join(lines)
text3
# Out:
# 'Public Key Cryptography\n In this note, we discuss a very nice and important application of modular arithmetic: the RSA public-key\n cryptosystem, named after its inventors Ronald Rivest, Adi Shamir and Leonard Adleman.\n The basic setting for cryptography is typically described via a cast of three characters: Alice and Bob, who\n with to communicate confidentially over some (insecure) link, and Eve, an eavesdropper who is listening in\n and trying to discover what they are saying. Let’s assume that Alice wants to transmit a message x (written\n in binary) to Bob. She will apply her encryption function E to x and send the encrypted message E(x) over\n the link; Bob, upon receipt of E(x), will then apply his decryption function D to it and thus recover the\n original message: i.e., D(E(x)) = x.\n Since the link is insecure, Alice and Bob have to assume that Eve may get hold of E(x). (Think of Eve\n as being a “sniffer" on the network.) Thus ideally we would like to know that the encr
# ...

# %%
from rake_nltk import Rake

r = Rake() # Uses stopwords for english from NLTK, and all puntuation characters.

r.extract_keywords_from_text(text3)

r.get_ranked_phrases() # To get keyword phrases ranked highest to lowest.
# Out:
# ['certain basic assumptions explained later',
#  'eve may get hold',
#  'typically described via',
#  'least partially figure',
#  'inventors ronald rivest',
#  'central idea behind',
#  'almost sounds impossible',
#  'bob meet beforehand',
#  'many encrypted messages',
#  'message without ever',
#  'encryption function e',
#  'public key known',
#  'private key known',
#  'thus retrieving x',
#  'digital lock public',
#  'understand alice ’',
#  'encrypted message e',
#  'original message x',
#  'public key cryptography',
#  'using bob ’',
#  'basic setting',
#  'encrypted messages',
#  'digital lock',
#  'original message',
#  'public key',
#  'private key',
#  'eve ’',
#  'without knowing',
#  'decryption function',
#  'message x',
#  'thus recover',
#  'thus ideally',
#  'called private',
#  'secure message',
#  'key schemes',
#  'key protocols',
#  'key cryptosystem',
#  'let ’',
#  'knowing e',
#  'functions e',
#  'e .,',
#  'x ).',
#  'x ),',
#  'x ))',
#  'rsa public',
# ...
